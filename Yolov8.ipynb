# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8

# %%
# %pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Git clone method (for development)

# %cd /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8

#Clone YOLOv8 from repository Ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 29310, done.
# remote: Counting objects: 100% (1529/1529), done.
# remote: Compressing objects: 100% (936/936), done.
# remote: Total 29310 (delta 997), reused 984 (delta 593), pack-reused 27781
# Receiving objects: 100% (29310/29310), 15.21 MiB | 14.23 MiB/s, done.
# Resolving deltas: 100% (20918/20918), done.

# %%
# %cd {HOME}/ultralytics
# %pip install -e .

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# Setup complete ✅ (32 CPUs, 62.5 GB RAM, 238.4/1830.5 GB disk)

# %%
# !mkdir {HOME}/Datasets
# %cd {HOME}/Datasets
# Out:
# mkdir: cannot create directory ‘{HOME}/Datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/Datasets'
# /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8
# /home/am10543y/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
import yaml

data = {'train' :  '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/train/images',
        'val' :  '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/valid/images',
        'test' : '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images',
        'nc': 30,
        'names': ['EM', 'IC', 'LED', 'battery', 'button', 'buzzer', 'capacitor', 'clock', 
                  'component text', 'connector', 'diode', 'display', 
                  'electrolytic capacitor', 'emi filter', 'ferrite bead', 
                  'fuse', 'heatsink', 'inductor', 'jumper', 'pads', 'pins',
                  'potentiometer', 'relay', 'resistor', 'switch', 'test point', 
                  'transducers', 'transformer', 'transistor', 'unknown']
        }

# overwrite the data to the .yaml file
with open('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/new_data.yaml', 'w') as f:
    yaml.dump(data, f)

# read the content in .yaml file
with open('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/new_data.yaml', 'r') as f:
    hamster_yaml = yaml.safe_load(f)
    display(hamster_yaml)
# Out:
# {'names': ['EM',
#   'IC',
#   'LED',
#   'battery',
#   'button',
#   'buzzer',
#   'capacitor',
#   'clock',
#   'component text',
#   'connector',
#   'diode',
#   'display',
#   'electrolytic capacitor',
#   'emi filter',
#   'ferrite bead',
#   'fuse',
#   'heatsink',
#   'inductor',
#   'jumper',
#   'pads',
#   'pins',
#   'potentiometer',
#   'relay',
#   'resistor',
#   'switch',
#   'test point',
#   'transducers',
#   'transformer',
#   'transistor',
#   'unknown'],
#  'nc': 30,
#  'test': '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images',
#  'train': '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/train/images',
#  'val': '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/valid/images'}

# %%
from ultralytics import YOLO
model = YOLO('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/ultralytics/ultralytics/cfg/models/v8/yolov8s.yaml')
#model = YOLO('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/yolov8s.pt')
#model = YOLO('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/ultralytics/ultralytics/cfg/models/v8/yolov8s.yaml').load('/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/yolov8s.pt')

# %%
#results=model.tune(data = '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/new_data.yaml', epochs=50, iterations=50, workers=16, optimizer='AdamW', plots=False, save=False, val=False)

# %%
#%cd {HOME}
results = model.train(data = '/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/new_data.yaml', epochs=150, imgsz=1280, patience=100, max_det=500, plots=True )
#!yolo task=detect mode=train model=yolov8s.pt data=/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/new_data.yaml epochs=200 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# ...

# %%
#%cd {HOME}
# !yolo task=detect mode=predict model=/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/runs/detect/train24/weights/best.pt conf=0.25 source=/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images save=True
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# YOLOv8s summary (fused): 168 layers, 11137194 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/990 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/ACM-109_Top_jpg.rf.07f4f2c9646ed11cbef7c1cafa619e4e.jpg: 1280x1280 1 IC, 1 LED, 2 capacitors, 1 clock, 3 resistors, 4.9ms
# image 2/990 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/ACM-109_Top_jpg.rf.103ec761a2e8f7640f33413b0e3a3c0d.jpg: 1280x1280 1 IC, 1 LED, 4 capacitors, 1 resistor, 1 test point, 4.8ms
# image 3/990 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/ACM-109_Top_jpg.rf.25c76b378ebf50a3ad8f33a453c998dc.jpg: 1280x1280 1 IC, 2 capacitors, 1 connector, 2 padss, 1 resistor, 4.5ms
# ...

# %%
#%cd {HOME}
# !yolo task=detect mode=predict model=/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/ultralytics/runs/detect/train/weights/best.pt conf=0.25 source=/home/am10543y/Downloads/pcb_9f_cc_9.png save=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A40-16C, 16187MiB)
# Model summary (fused): 168 layers, 11137194 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /home/am10543y/Downloads/pcb_9f_cc_9.png: 672x800 9 ICs, 5 LEDs, 4 capacitors, 2 electrolytic capacitors, 12 resistors, 113.4ms
# Speed: 9.6ms preprocess, 113.4ms inference, 432.7ms postprocess per image at shape (1, 3, 672, 800)
# Results saved to /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/ultralytics/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/runs/detect/predict/*.jpg')[:6]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
def get_preidction_rect_list(prediction_result):
    rect_list = []
    p = prediction_result[0].boxes.xywh.detach().cpu().numpy()
    from matplotlib import patches
    for item in p:
        rect = patches.Rectangle((item[0]-item[2]/2, item[1]-item[3]/2), item[2], item[3], linewidth=1, edgecolor='r', facecolor='none')
        rect_list.append(rect)

    return rect_list

def get_ground_truth_rect_list(label_path,img_shape):

    with open(label_path, 'r') as file:
        labels = file.readlines()

    image_height, image_width, _ = img_shape
    from matplotlib import patches
    rect_list = []
    for label in labels:
        class_id, x_center, y_center, width, height = map(float, label.strip().split())
        class_name = ''

        # Convert YOLO format to bounding box coordinates
        x_center *= image_width
        y_center *= image_height
        width *= image_width
        height *= image_height

        x_min = x_center - width / 2
        y_min = y_center - height / 2

        # Create a Rectangle patch
        rect = patches.Rectangle((x_min, y_min), width, height, linewidth=1, edgecolor='g', facecolor='none')
        rect_list.append(rect)

    return rect_list

# %%
from ultralytics import YOLO
import random
import os,glob
import cv2


if __name__=="__main__":

    root_path = "/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8" ## Working Directory

    data_path = "/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test"
    imgage_list = glob.glob(os.path.join("/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images","*.jpg"))

    checkpoint_path = os.path.join("/home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/runs/detect/train24/weights/best.pt")
    print('Loading Model')
    model = YOLO(checkpoint_path)
    print('Finish Loading Model')

    import matplotlib.pyplot as plt
    fig,ax = plt.subplots(2,5,sharex=True,sharey=True)
    for i in range(5):
        image_path = imgage_list[random.randint(0, len(imgage_list))]

        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        label_path = image_path.replace(".jpg", ".txt")
        label_path = os.path.join(root_path, data_path, "labels", image_path.split("/")[-1].replace(".jpg", ".txt"))

        ground_truth_rect_list = get_ground_truth_rect_list(label_path,img_shape=image.shape)

        ax[0][i].imshow(image)
        for rect in ground_truth_rect_list:
            ax[0][i].add_patch(rect)
        ax[0][i].set_title('Ground Truth')

        result = model.predict(image_path)
        prediction_rect_list = get_preidction_rect_list(result)

        ax[1][i].imshow(image)
        for rect in prediction_rect_list:
            ax[1][i].add_patch(rect)
        ax[1][i].set_title('Prediction')

    plt.show()
# Out:
# Loading Model
# Finish Loading Model
#
# image 1/1 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/PCBA_603_jpg.rf.dbe7e34c998ee0c56c78c43ca363f36a.jpg: 1280x1280 1 inductor, 7.4ms
# Speed: 6.4ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# image 1/1 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/PCBA_117_jpg.rf.40113f8adc49a0a8b34afa227097741a.jpg: 1280x1280 1 IC, 1 buzzer, 1 capacitor, 1 potentiometer, 1 resistor, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# image 1/1 /home/am10543y/Documents/Summer_Project/Deep_learning_Models/Yolov8/Datasets/Internship/test/images/pcb6rec1_jpg.rf.ab872dfb43892985f74e4732f4482909.jpg: 1280x1280 2 ICs, 2 resistors, 7.6ms
# Speed: 4.0ms preprocess, 7.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# ...
